# %%
import pandas as pd
import glob

# %%
path='C:/Users/Lohit/Desktop/krr/GroupA/raw data/'  # folder path
all_files=glob.glob(path+"/*.csv")    #extracting all the csv files fromt the folder
all_files
# Out:
# ['C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS402CompilerConstructionSectionBCS9A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS4050 - Information Systems Audit and Control Section BCS-7A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS4057 - Agile Software Project Management Section BCS-8B.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS494 - IS Audit and Control Section BCS-7A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS5031 - Applied Computer Vision Section MCS-2A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS5047 - Software Processes and Quality Assurance Section MSP-3A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS518 - Software Quality Assurance Section MSP-1A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS535 - Natural Language Processing Section MDS-1A.csv',
#  'C:/Users/Lohit/Desktop/krr/GroupA/raw data\\CS570 - Advance Data Warehousing and Data Mining Section MSP-2A.csv',
# ...

# %%
data=pd.read_csv(all_files[0]) #extracting 1st file data 
data.head(10) # visualizing the data
# Out:
#                                           Unnamed: 0    NUCES, KHI  \
# 0          Student Course Evaluation Analysis Report           NaN
# 1   CS402 - Compiler Construction     Section:BCS-9A           NaN
# 2                                        Instructor:  Sayed Yousuf
# 3  4=Strongly Agree, 3=Agree,  2=Uncertain, 1=Dis...           NaN
# 4                                                NaN   CGPA Range:
# 5                                           Question           NaN
# 6                    Course Content and organization           NaN
# 7                   1 The course objective was clear           NaN
# 8               2 The course workload was manageable           NaN
# 9  3 The course was well organized ( e.g. timely ...           NaN
#
#                       Unnamed: 2    Unnamed: 3           Unnamed: 4  \
# 0                            NaN           NaN          Spring 2021
# 1                            NaN           NaN      Date: 28-Nov-22
# ...

# %%
course=data.iloc[1,0] # extracting the course code 
print(course)
print(course[:course.find("-")])
teacher=data.iloc[2,1]  # extracting the teacher name
teacher
# Out:
# CS402 - Compiler Construction     Section:BCS-9A
# CS402
# 'Sayed Yousuf'

# %%
data.head(10)
# Out:
#                                           Unnamed: 0    NUCES, KHI  \
# 0          Student Course Evaluation Analysis Report           NaN
# 1   CS402 - Compiler Construction     Section:BCS-9A           NaN
# 2                                        Instructor:  Sayed Yousuf
# 3  4=Strongly Agree, 3=Agree,  2=Uncertain, 1=Dis...           NaN
# 4                                                NaN   CGPA Range:
# 5                                           Question           NaN
# 6                    Course Content and organization           NaN
# 7                   1 The course objective was clear           NaN
# 8               2 The course workload was manageable           NaN
# 9  3 The course was well organized ( e.g. timely ...           NaN
#
#                       Unnamed: 2    Unnamed: 3           Unnamed: 4  \
# 0                            NaN           NaN          Spring 2021
# 1                            NaN           NaN      Date: 28-Nov-22
# ...

# %%
data=data.iloc[6:,17:] # extracting columns----> wt,avg,prod
data
# Out:
#    Unnamed: 17 Unnamed: 18 Unnamed: 19
# 6          NaN         NaN         NaN
# 7            0        2.92           0
# 8            1        3.03        3.03
# 9            1        2.95        2.95
# 10         NaN         NaN         NaN
# ..         ...         ...         ...
# 62       69.38           %         NaN
# 63         NaN         NaN         NaN
# 64         NaN         NaN         NaN
# 65         NaN         NaN         NaN
# 66         NaN         NaN         NaN
#
# [61 rows x 3 columns]

# %%
data=data.dropna() # removing the rows that contains Nan values
data=data.reset_index(drop=True)  # reset index
data
# Out:
#    Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0            0        2.92           0
# 1            1        3.03        3.03
# 2            1        2.95        2.95
# 3            1        3.18        3.18
# 4            1        3.21        3.21
# 5            1        3.08        3.08
# 6            0        3.08           0
# 7            1        3.18        3.18
# 8            1        3.23        3.23
# 9            1        3.23        3.23
# 10           1        3.15        3.15
# 11           1        3.21        3.21
# 12           1        2.95        2.95
# 13           0        3.08           0
# 14           1        3.26        3.26
# 15           1        3.23        3.23
# 16           0        3.13           0
# 17           0        3.05           0
# 18           1         3.1         3.1
# 19           1        3.13        3.13
# 20           1        3.15        3.15
# 21           0        3.13           0
# 22           0        3.05           0
# ...

# %%
df=pd.read_csv(r'C:\Users\Lohit\Desktop\krr\feedback.csv') 
df=df.iloc[:,2:4] #Selecting perfect format for questions with respect to their type
df
# Out:
#                                          Type  \
# 0             Course Content and organization
# 1             Course Content and organization
# 2             Course Content and organization
# 3                          Teacher Evaluation
# 4                          Teacher Evaluation
# 5                          Teacher Evaluation
# 6                          Teacher Evaluation
# 7                          Teacher Evaluation
# 8                          Teacher Evaluation
# 9                          Teacher Evaluation
# 10                         Teacher Evaluation
# 11                         Teacher Evaluation
# 12                         Teacher Evaluation
# 13                         Teacher Evaluation
# 14                         Teacher Evaluation
# 15                         Teacher Evaluation
# 16                         Teacher Evaluation
# 17                       Student Contribution
# 18                       Student Contribution
# ...

# %%
# forming the list of values for dataframes
Teacher=[teacher for _ in range(len(data.axes[0]))] 
Course=[course for _ in range(len(data.axes[0]))]
typee=list(df.iloc[:len(data.axes[0]),0].values)
question=list(df.iloc[:len(data.axes[0]),1].values)
wt=list(data.iloc[:,0].values)
avg=list(data.iloc[:,1].values)
prod=list(data.iloc[:,2].values)

print(Teacher)
print(len(Course))
print(len(typee))
print(len(question))
print(len(wt))
print(len(avg))
print(len(prod))
# Out:
# ['Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf', 'Sayed Yousuf']
# 35
# 35
# 35
# 35
# 35
# 35

# %%
# forming data frame and append to the the file
df=pd.DataFrame({'Teacher':Teacher,'Course':Course ,'2':typee,'3':question,'4':wt,'5':avg,'6':prod })
df.to_csv(r'C:\Users\Lohit\Desktop\krr\feedback.csv',mode='a',index=False,header=False)
